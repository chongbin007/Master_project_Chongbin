# %%
import  pandas as pd
import  matplotlib.pyplot as plt
import  csv

# %%
sample_data = pd.read_csv('mean_times.csv')

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_1)
plt.plot(sample_data.id,sample_data.mean_time_ms_10)
plt.plot(sample_data.id,sample_data.mean_time_ms_100)
plt.plot(sample_data.id,sample_data.mean_time_ms_200)
plt.plot(sample_data.id,sample_data.mean_time_ms_400)
plt.plot(sample_data.id,sample_data.mean_time_ms_500)
plt.plot(sample_data.id,sample_data.mean_time_ms_600)
plt.plot(sample_data.id,sample_data.mean_time_ms_800)
plt.plot(sample_data.id,sample_data.mean_time_ms_1000)
plt.plot(sample_data.id,sample_data.mean_time_ms_2000)
plt.plot(sample_data.id,sample_data.mean_time_ms_5000)
plt.plot(sample_data.id,sample_data.mean_time_ms_10000)
plt.plot(sample_data.id,sample_data.mean_time_ms_15000)
plt.plot(sample_data.id,sample_data.mean_time_ms_20000)

##设置ax4中legend的位置，将其放在图外
plt.legend(["1","10","100","200","400","500","600","800","1000","2000","5000","10000","15000","20000"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率

plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
# plt.savefig('plottest.png', dpi=300) #指定分辨率保存

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_1)
plt.plot(sample_data.id,sample_data.mean_time_ms_10)
plt.plot(sample_data.id,sample_data.mean_time_ms_200)
plt.plot(sample_data.id,sample_data.mean_time_ms_400)
plt.plot(sample_data.id,sample_data.mean_time_ms_600)
plt.plot(sample_data.id,sample_data.mean_time_ms_1000)
plt.plot(sample_data.id,sample_data.mean_time_ms_5000)
plt.plot(sample_data.id,sample_data.mean_time_ms_10000)
plt.plot(sample_data.id,sample_data.mean_time_ms_20000)

##设置ax4中legend的位置，将其放在图外
plt.legend(["1","10","200","400","600","1000","5000","10000","20000"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
#plt.rcParams["figure.figsize"] = [7, 4] #画布大小


plt.ylim((0, 25))
plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
#plt.savefig('all1.png', dpi=200) #指定分辨率保存

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_1)
plt.plot(sample_data.id,sample_data.mean_time_ms_10)

##设置ax4中legend的位置，将其放在图外
plt.legend(["1","10"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率


plt.ylim((0, 20))
plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
#plt.savefig('low1.png', dpi=300) #指定分辨率保存

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_100)
plt.plot(sample_data.id,sample_data.mean_time_ms_200)
plt.plot(sample_data.id,sample_data.mean_time_ms_400)
plt.plot(sample_data.id,sample_data.mean_time_ms_600)
plt.plot(sample_data.id,sample_data.mean_time_ms_800)
plt.plot(sample_data.id,sample_data.mean_time_ms_1000)


##设置ax4中legend的位置，将其放在图外
plt.legend(["100","200","400","600","800","1000"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率

plt.ylim((0, 21))
plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
#plt.savefig('middle1.png', dpi=300) #指定分辨率保存

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_1000)
plt.plot(sample_data.id,sample_data.mean_time_ms_2000)
plt.plot(sample_data.id,sample_data.mean_time_ms_10000)
plt.plot(sample_data.id,sample_data.mean_time_ms_20000)

##设置ax4中legend的位置，将其放在图外
plt.legend(["1000","2000","10000","20000"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率

plt.ylim((0, 25))
plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
#plt.savefig('plottest.png', dpi=300) #指定分辨率保存

# %%
plt.plot(sample_data.id,sample_data.mean_time_ms_80000)
plt.plot(sample_data.id,sample_data.mean_time_ms_1000000)
plt.plot(sample_data.id,sample_data.mean_time_ms_50000)
plt.plot(sample_data.id,sample_data.mean_time_ms_200000)

##设置ax4中legend的位置，将其放在图外
plt.legend(["80000","1000000","50000","200000"],loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)    

plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率

plt.title("Message Latency")
plt.xlabel("Message id")
plt.ylabel("Message latency (ms)")
plt.show()
# plt.savefig('plottest.png', dpi=300) #指定分辨率保存
